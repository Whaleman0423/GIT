# %% [markdown]
# <a href="https://colab.research.google.com/github/Whaleman0423/GIT/blob/main/Git_%E5%9F%BA%E7%A4%8E%E4%B8%8A%E5%82%B3%E6%AA%94%E6%A1%88%E8%AA%9E%E6%B3%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git 常用指令:
# ##1. git add
# ##2. git commit
# ##3. git push

# %% [markdown]
# # 第一步: 安裝 git bash :https://gitforwindows.org/
# ## 在 Windows 作業系統下
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 第二步: 建立專案資料夾  ( 此處建立hello資料夾
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 第三步: 在資料夾中 右鍵 打開 git bash
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 第四步: 初始化資料夾 : git init
# ![image.png](data:image/png;base64,...)
# 3

# %% [markdown]
# ### 在專案資料夾中新增一個 hello.txt
# ### 並在 bash命令框中輸入 $git status
# #### Untracked file : 尚未加入 git 的追蹤的檔案

# %% [markdown]
# #第五步: 把檔案加入 git 追蹤
# ## 在 bash 命令框 輸入 \$git add hello.txt
# ### 輸入 \$git status 觀察結果，

# %% [markdown]
# # 第六步: 利用 git commit 進行存檔
# ###輸入 \$git commit -m "你要commit的存檔名稱"
# ![image.png](data:image/png;base64,...)
#
# ## 完成後，用 git status 查看結果
# ## 輸入 \$git log 查看你的 commit 內容

# %% [markdown]
# ## 當 hello.txt 內容有更動
# ## 輸入 \$git status hello.txt 又會跳出來

# %% [markdown]
# # \$git add . => . 代表目前所在資料夾  => 將目前資料夾的所有檔案都加入 git 追蹤

# %% [markdown]
# # 第七步: 至 github 新增帳號，並建立 repository 準備上傳檔案到 repository

# %% [markdown]
# # 第八步: 將 github 專案資料夾與自己本地端做連結
# ### 輸入 \$git remote add origin https:************

# %% [markdown]
# ## git remote add <自訂名稱> <網址>

# %% [markdown]
# # 連結後 輸入 \$git remote 查看連結結果

# %% [markdown]
# # 最後一步: 上傳檔案
# ### 輸入 \$git push -u origin mster
# #### -u => 將 origin 這個路徑 設為預設， 以後上傳到 origin ，只要輸入 \$git push
# # master = > 目前所在的 branch ， 可以創建許多branch ，
